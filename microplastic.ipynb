# %%
import json

kaggle_dict = {
 "username": "Itachi@Uchiha92",
 "key": "KGAT_0c9c60d2abd177519606789101878d45"
}

with open("kaggle.json","w") as f:
    json.dump(kaggle_dict,f)

# %%
import os
print(os.listdir('.'))

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets list
# Out:
# ref                                                          title                                                    size  lastUpdated                 downloadCount  voteCount  usabilityRating
# -----------------------------------------------------------  -------------------------------------------------  ----------  --------------------------  -------------  ---------  ---------------
# dmahajanbe23/bmw-global-automotive-sales                     BMW Global Automotive Sales                             55017  2026-02-22 18:18:38.170000           8314        164  1.0
# shree0910/ai-and-data-science-job-market-dataset-20202026    AI & Data Science Job Market Dataset (2020–2026)       188367  2026-03-09 07:40:43.393000           1653         43  1.0
# ssssws/chocolate-sales-dataset-2023-2024                     Chocolate Sales Dataset 2023 - 2024                  24420255  2026-03-07 04:58:02.387000           2194         50  1.0
# ...

# %%
# !kaggle datasets download -d federicoborzacchiello/microplastics
# Out:
# 403 Client Error: Forbidden for url: https://www.kaggle.com/api/v1/datasets/metadata/federicoborzacchiello/microplastics

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir -p /content/drive/MyDrive/microplastic_dataset

# %%
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.8/95.8 kB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 22.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 70.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 89.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="0K4sZnVTLoEbZPQnZZRN")
project = rf.workspace("walailak-university-fearv").project("microplastic-nuga5")
dataset = project.version(7).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to MicroPlastic-7 in yolov8:: 100%|██████████| 809/809 [00:00<00:00, 5655.51it/s]

# %%
# !cp -r microplastic-nuga5-7 /content/drive/MyDrive/microplastic_dataset/
# Out:
# cp: cannot stat 'microplastic-nuga5-7': No such file or directory

# %%
# !ls
# Out:
# drive  MicroPlastic-7  sample_data

# %%
# !cp -r /content/MicroPlastic-7 /content/drive/MyDrive/

# %%
# !ls /content/drive/MyDrive/
# Out:
# 'Audio_Signal_Filtering(2).gslides'   EDP_F2.gdoc      microplastic_dataset
# 'Colab Notebooks'		      MicroPlastic-7   Microplastic_Project

# %%
# !ls /content/MicroPlastic-7
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  train  valid

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 17.9 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO("yolov8n.pt")

# %%
model.train(
    data="/content/MicroPlastic-7/data.yaml",
    epochs=50,
    imgsz=640,
    batch=16
)
# Out:
# Ultralytics 8.4.22 🚀 Python-3.12.12 torch-2.10.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
# !ls /content/drive/MyDrive/
# Out:
# ls: cannot access '/content/drive/MyDrive/': No such file or directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/
# Out:
# 'Audio_Signal_Filtering(2).gslides'   EDP_F2.gdoc      microplastic_dataset
# 'Colab Notebooks'		      MicroPlastic-7   Microplastic_Project

# %%
# !ls /content/drive/MyDrive/MicroPlastic-7
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  train  valid

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/drive/MyDrive/MicroPlastic-7/data.yaml",
    epochs=50,
    imgsz=640
)
# Out:
# Ultralytics 8.4.22 🚀 Python-3.12.12 torch-2.10.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/
# Out:
# 'Audio_Signal_Filtering(2).gslides'   EDP_F2.gdoc      microplastic_dataset
# 'Colab Notebooks'		      MicroPlastic-7   Microplastic_Project

# %%
# !ls /content/drive/MyDrive/MicroPlastic-7
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  train  valid

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/drive/MyDrive/MicroPlastic-7/data.yaml",
    epochs=50,
    imgsz=640
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_11184/1870117045.py in <cell line: 0>()
# ----> 1 from ultralytics import YOLO
#       2
#       3 model = YOLO("yolov8n.pt")
#       4
#       5 model.train(
#
# ModuleNotFoundError: No module named 'ultralytics'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 30.8 MB/s eta 0:00:00
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.22 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 43.5/112.6 GB disk)

# %%
from ultralytics import YOLO

# %%
# !pip install ultralytics

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls /content/drive/MyDrive/MicroPlastic-7
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  train  valid

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/drive/MyDrive/MicroPlastic-7/data.yaml",
    epochs=50,
    imgsz=640
)
# Out:
# ...
# Ultralytics 8.4.22 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO("/content/runs/detect/train/weights/best.pt")

# %%
results = model.predict(
    source="/content/2_png_jpg.rf.1d6e254b57f231d26182a4b7a8f13513.jpg",
    conf=0.25
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_11184/1531164136.py in <cell line: 0>()
# ----> 1 results = model.predict(
#       2     source="/content/2_png_jpg.rf.1d6e254b57f231d26182a4b7a8f13513.jpg",
#       3     conf=0.25
#       4 )
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in predict(self, source, stream, predictor, **kwargs)
#     534         if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     535             self.predictor.set_prompts(prompts)
# --> 536         return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#     537
#     538     def track(
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/predictor.py in __call__(self, source, model, stream, *args, **kwargs)
# ...

# %%
results = model.predict(
    source="/content/2_png_jpg.rf.1d6e254b57f231d26182a4b7a8f13513.jpg",
    conf=0.25
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_11184/1531164136.py in <cell line: 0>()
# ----> 1 results = model.predict(
#       2     source="/content/2_png_jpg.rf.1d6e254b57f231d26182a4b7a8f13513.jpg",
#       3     conf=0.25
#       4 )
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in predict(self, source, stream, predictor, **kwargs)
#     534         if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     535             self.predictor.set_prompts(prompts)
# --> 536         return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#     537
#     538     def track(
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/predictor.py in __call__(self, source, model, stream, *args, **kwargs)
# ...

# %%
# !ls /content/drive/MyDrive/MicroPlastic-7/valid/images
# Out:
# 100_png_jpg.rf.0b73e1e3d389c6c6b192e0494a08d773.jpg
# 11_png_jpg.rf.f2508cd160df8602fa7cd798020980b9.jpg
# 12_png_jpg.rf.0d924962cb7ee3ff93c2649ebe9fd5ff.jpg
# 14_png_jpg.rf.aa5c759bd47d96fc21ec0c8aa987a69d.jpg
# 16_png_jpg.rf.0771260bf9e7b6e03ed0ee2129b37238.jpg
# 17_png_jpg.rf.0dde4d08842274081d32b30e7ba25df5.jpg
# 18_png_jpg.rf.ac6bf07534a46b9103b447976ea86160.jpg
# 19_png_jpg.rf.0b01b068df914ed78a822d4e5c9ea561.jpg
# 1_png_jpg.rf.2b48c20931b7eab3302cdaa419f93796.jpg
# 20_png_jpg.rf.4eab8116ee14adc4761d2f2fb454f618.jpg
# 21_png_jpg.rf.c18bb6a0f5639c85fbd764a9dcd93dcf.jpg
# 22_png_jpg.rf.2f5ab8b47a5cb74cec2329bbb295b09b.jpg
# 23_png_jpg.rf.d839f25c7ceb20bd718c1b1645a299b4.jpg
# 24_png_jpg.rf.c98abffc643c0e328a2abe81e7f939d9.jpg
# 26_png_jpg.rf.65b8b9cfb3d2730ba8fbe78b2d856844.jpg
# 27_png_jpg.rf.1d5f17b4b61e66b8caae54273aeb2745.jpg
# 29_png_jpg.rf.db0ef36b216e8c5957d4d660a5c75a1a.jpg
# 30_png_jpg.rf.27f53030615e56408488c397c757e39c.jpg
# ...

# %%
results = model.predict(
    source="/content/drive/MyDrive/MicroPlastic-7/valid/images/7_png_jpg.rf.d42f1f0391195eecedeb6d524b446928.jpg",
    conf=0.25,
    save=True
)
# Out:
# image 1/1 /content/drive/MyDrive/MicroPlastic-7/valid/images/7_png_jpg.rf.d42f1f0391195eecedeb6d524b446928.jpg: 640x640 2 fibers, 2 films, 1 fragment, 3 pallets, 9.2ms
# Speed: 6.2ms preprocess, 9.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/detect/predict

# %%
# !ls /content/runs/detect/predict
# Out:
# 7_png_jpg.rf.d42f1f0391195eecedeb6d524b446928.jpg

# %%
from IPython.display import Image
Image("/content/runs/detect/predict/7_png_jpg.rf.d42f1f0391195eecedeb6d524b446928.jpg")

# %%
counts = {"fiber":2, "film":2, "fragment":1, "pellet":3}

total = sum(counts.values())

if total < 5:
    severity = "Low Pollution"
elif total < 15:
    severity = "Moderate Pollution"
else:
    severity = "High Pollution"

if severity == "Low Pollution":
    treatment = "Basic filtration and sedimentation recommended."
elif severity == "Moderate Pollution":
    treatment = "Activated carbon filtration and membrane filtration recommended."
else:
    treatment = "Advanced treatment such as ultrafiltration or reverse osmosis required."

print("------ MICROPLASTIC ANALYSIS REPORT ------")
print("Fiber:", counts["fiber"])
print("Film:", counts["film"])
print("Fragment:", counts["fragment"])
print("Pellet:", counts["pellet"])
print("Total Microplastics:", total)
print("Pollution Level:", severity)
print("Recommended Treatment:", treatment)
# Out:
# ------ MICROPLASTIC ANALYSIS REPORT ------
# Fiber: 2
# Film: 2
# Fragment: 1
# Pellet: 3
# Total Microplastics: 8
# Pollution Level: Moderate Pollution
# Recommended Treatment: Activated carbon filtration and membrane filtration recommended.

# %%
from ultralytics import YOLO

model = YOLO("/content/runs/detect/train/weights/best.pt")

# %%
results = model.predict(
    source="/content/drive/MyDrive/MicroPlastic-7/valid/images/7_png_jpg.rf.d42f1f0391195eecedeb6d524b446928.jpg",
    conf=0.25
)
# Out:
# image 1/1 /content/drive/MyDrive/MicroPlastic-7/valid/images/7_png_jpg.rf.d42f1f0391195eecedeb6d524b446928.jpg: 640x640 2 fibers, 2 films, 1 fragment, 3 pallets, 7.3ms
# Speed: 2.6ms preprocess, 7.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)

# %%
counts = {"fiber":0, "fragment":0, "film":0, "pellet":0}

for r in results:
    for cls in r.boxes.cls:
        label = model.names[int(cls)].lower()
        counts[label] += 1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_11184/1511206059.py in <cell line: 0>()
#       4     for cls in r.boxes.cls:
#       5         label = model.names[int(cls)].lower()
# ----> 6         counts[label] += 1
#
# KeyError: 'pallet'

# %%
counts = {name.lower(): 0 for name in model.names.values()}

for r in results:
    for cls in r.boxes.cls:
        label = model.names[int(cls)].lower()
        counts[label] += 1

# %%
counts = {name.lower(): 0 for name in model.names.values()}

for r in results:
    for cls in r.boxes.cls:
        label = model.names[int(cls)].lower()
        counts[label] += 1

total = sum(counts.values())

if total < 5:
    severity = "Low Pollution"
elif total < 15:
    severity = "Moderate Pollution"
else:
    severity = "High Pollution"

if severity == "Low Pollution":
    treatment = "Basic filtration and sedimentation recommended."
elif severity == "Moderate Pollution":
    treatment = "Activated carbon filtration or membrane filtration recommended."
else:
    treatment = "Advanced treatment such as ultrafiltration or reverse osmosis required."

print("----- MICROPLASTIC ANALYSIS REPORT -----")

for k,v in counts.items():
    print(k.capitalize()+":", v)

print("Total Microplastics:", total)
print("Pollution Level:", severity)
print("Recommended Treatment:", treatment)
# Out:
# ----- MICROPLASTIC ANALYSIS REPORT -----
# Fiber: 2
# Film: 2
# Fragment: 1
# Pallet: 3
# Total Microplastics: 8
# Pollution Level: Moderate Pollution
# Recommended Treatment: Activated carbon filtration or membrane filtration recommended.

# %%
from ultralytics import YOLO

model = YOLO("/content/runs/detect/train/weights/best.pt")

def analyze_microplastic(image_path):

    results = model.predict(source=image_path, conf=0.25)

    counts = {name.lower():0 for name in model.names.values()}

    for r in results:
        for cls in r.boxes.cls:
            label = model.names[int(cls)].lower()
            counts[label] += 1

    total = sum(counts.values())

    if total < 5:
        severity = "Low Pollution"
    elif total < 15:
        severity = "Moderate Pollution"
    else:
        severity = "High Pollution"

    if severity == "Low Pollution":
        treatment = "Basic filtration and sedimentation recommended."
    elif severity == "Moderate Pollution":
        treatment = "Activated carbon filtration or membrane filtration recommended."
    else:
        treatment = "Advanced treatment such as ultrafiltration or reverse osmosis required."

    print("\n===== MICROPLASTIC ANALYSIS REPORT =====\n")

    for k,v in counts.items():
        print(k.capitalize()+":", v)

    print("\nTotal Microplastics:", total)
    print("Pollution Level:", severity)
    print("Recommended Treatment:", treatment)

# %%
analyze_microplastic("/content/drive/MyDrive/MicroPlastic-7/valid/images/7_png_jpg.rf.d42f1f0391195eecedeb6d524b446928.jpg

.jpg")

# %%
analyze_microplastic("/content/drive/MyDrive/MicroPlastic-7/valid/images/7_png_jpg.rf.d42f1f0391195eecedeb6d524b446928.jpg")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_10240/1527078286.py in <cell line: 0>()
# ----> 1 analyze_microplastic("/content/drive/MyDrive/MicroPlastic-7/valid/images/7_png_jpg.rf.d42f1f0391195eecedeb6d524b446928.jpg")
#
# NameError: name 'analyze_microplastic' is not defined

# %%
analyze_microplastic("/content/drive/MyDrive/MicroPlastic-7/valid/images/7_png_jpg.rf.d42f1f0391195eecedeb6d524b446928.jpg.jpg")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_10240/1548046429.py in <cell line: 0>()
# ----> 1 analyze_microplastic("/content/drive/MyDrive/MicroPlastic-7/valid/images/7_png_jpg.rf.d42f1f0391195eecedeb6d524b446928.jpg.jpg")
#
# NameError: name 'analyze_microplastic' is not defined

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 23.8 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO("/content/drive/MyDrive/runs/detect/train/weights/best.pt")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_10240/1824012805.py in <cell line: 0>()
#       1 from ultralytics import YOLO
#       2
# ----> 3 model = YOLO("/content/drive/MyDrive/runs/detect/train/weights/best.pt")
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/models/yolo/model.py in __init__(self, model, task, verbose)
#      74         else:
#      75             # Continue with default YOLO initialization
# ---> 76             super().__init__(model=model, task=task, verbose=verbose)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !find /content/drive/MyDrive -name "best.pt"

# %%
from ultralytics import YOLO

model = YOLO("/content/drive/MyDrive/runs/detect/train/weights/best.pt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_10240/1824012805.py in <cell line: 0>()
#       1 from ultralytics import YOLO
#       2
# ----> 3 model = YOLO("/content/drive/MyDrive/runs/detect/train/weights/best.pt")
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/models/yolo/model.py in __init__(self, model, task, verbose)
#      74         else:
#      75             # Continue with default YOLO initialization
# ---> 76             super().__init__(model=model, task=task, verbose=verbose)
#      77             if hasattr(self.model, "model") and "RTDETR" in self.model.model[-1]._get_name():  # if RTDETR head
#      78                 from ultralytics import RTDETR
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in __init__(self, model, task, verbose)
#     142             self._new(model, task=task, verbose=verbose)
# ...

# %%
# !pip install ultralytics

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/drive/MyDrive/MicroPlastic-7/data.yaml",
    epochs=50,
    imgsz=640
)
# Out:
# ...
# Ultralytics 8.4.22 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !cp -r /content/runs /content/drive/MyDrive/

# %%
# !ls /content/drive/MyDrive/
# Out:
# 'Audio_Signal_Filtering(2).gslides'   MicroPlastic-7	     runs
# 'Colab Notebooks'		      microplastic_dataset
#  EDP_F2.gdoc			      Microplastic_Project

# %%
# !ls /content/drive/MyDrive/runs
# Out:
# detect

# %%
# !ls /content/drive/MyDrive/runs/detect
# Out:
# train

# %%
# !ls /content/drive/MyDrive/runs/detect/train/weights
# Out:
# best.pt  last.pt

# %%
from ultralytics import YOLO

model = YOLO("/content/drive/MyDrive/runs/detect/train/weights/best.pt")

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-727af1b3-1947-4d11-8b29-3e574ae011d3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-727af1b3-1947-4d11-8b29-3e574ae011d3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
analyze_microplastic("/content/2_png_jpg.rf.1d6e254b57f231d26182a4b7a8f13513.jpg")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_10240/3526773478.py in <cell line: 0>()
# ----> 1 analyze_microplastic("/content/2_png_jpg.rf.1d6e254b57f231d26182a4b7a8f13513.jpg")
#
# NameError: name 'analyze_microplastic' is not defined

# %%
from ultralytics import YOLO

model = YOLO("/content/drive/MyDrive/runs/detect/train/weights/best.pt")

# %%
def analyze_microplastic(image_path):

    results = model.predict(source=image_path, conf=0.25)

    counts = {"fiber":0, "fragment":0, "film":0, "pellet":0}

    for r in results:
        for cls in r.boxes.cls:
            label = model.names[int(cls)].lower()
            if label in counts:
                counts[label] += 1

    total = sum(counts.values())

    print("------ MICROPLASTIC ANALYSIS REPORT ------")
    print("Fiber:", counts["fiber"])
    print("Fragment:", counts["fragment"])
    print("Film:", counts["film"])
    print("Pellet:", counts["pellet"])
    print("Total particles:", total)

    if total < 5:
        level = "Low contamination"
    elif total < 15:
        level = "Moderate contamination"
    else:
        level = "High contamination"

    print("Pollution Level:", level)
    print("------------------------------------------")

# %%
analyze_microplastic("/content/2_png_jpg.rf.1d6e254b57f231d26182a4b7a8f13513.jpg")
# Out:
# image 1/1 /content/2_png_jpg.rf.1d6e254b57f231d26182a4b7a8f13513.jpg: 640x640 1 fiber, 2 films, 1 fragment, 3 pallets, 9.0ms
# Speed: 2.4ms preprocess, 9.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# ------ MICROPLASTIC ANALYSIS REPORT ------
# Fiber: 1
# Fragment: 1
# Film: 2
# Pellet: 0
# Total particles: 4
# Pollution Level: Low contamination
# ------------------------------------------

# %%
results = model.predict(
    source="/content/2_png_jpg.rf.1d6e254b57f231d26182a4b7a8f13513.jpg",
    conf=0.25,
    save=True
)
# Out:
# image 1/1 /content/2_png_jpg.rf.1d6e254b57f231d26182a4b7a8f13513.jpg: 640x640 1 fiber, 2 films, 1 fragment, 3 pallets, 9.1ms
# Speed: 2.8ms preprocess, 9.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/detect/predict

# %%
results = model.predict(
    source="/content/2_png_jpg.rf.1d6e254b57f231d26182a4b7a8f13513.jpg",
    conf=0.25,
    save=True,
    show_labels=True,
    show_conf=True
)
# Out:
# image 1/1 /content/2_png_jpg.rf.1d6e254b57f231d26182a4b7a8f13513.jpg: 640x640 1 fiber, 2 films, 1 fragment, 3 pallets, 9.6ms
# Speed: 3.4ms preprocess, 9.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/detect/predict

# %%
from IPython.display import Image, display
display(Image("/content/runs/detect/predict/2_png_jpg.rf.1d6e254b57f231d26182a4b7a8f13513.jpg"))

# %%
def analyze_microplastic("/content/drive/MyDrive/MicroPlastic-7/valid/images/7_png_jpg.rf.d42f1f0391195eecedeb6d524b446928.jpg"):

    results = model.predict(source=image_path, conf=0.25)

    counts = {"fiber":0, "fragment":0, "film":0, "pellet":0}

    for r in results:
        for cls in r.boxes.cls:
            label = model.names[int(cls)].lower()

            if label == "pallet":   # fix label spelling
                label = "pellet"

            if label in counts:
                counts[label] += 1

    total = sum(counts.values())

    # Risk percentage estimation
    risk_percentage = min(100, total * 8)

    # Water usability
    if total <= 3:
        drinking = "Safe after basic filtration"
        irrigation = "Safe"
        aquatic = "Low impact"
        level = "Low contamination"

    elif total <= 10:
        drinking = "Not recommended"
        irrigation = "Acceptable with filtration"
        aquatic = "Moderate risk"
        level = "Moderate contamination"

    else:
        drinking = "Unsafe"
        irrigation = "Unsafe without treatment"
        aquatic = "High risk to aquatic life"
        level = "High contamination"

    # Treatment suggestions
    treatment = [
        "Membrane filtration",
        "Activated carbon filtration",
        "Advanced oxidation process",
        "Ultrafiltration or nanofiltration",
        "Microplastic sedimentation tanks"
    ]

    print("\n====== MICROPLASTIC ANALYSIS REPORT ======\n")

    print("Particle Count:")
    print("Fiber:", counts["fiber"])
    print("Fragment:", counts["fragment"])
    print("Film:", counts["film"])
    print("Pellet:", counts["pellet"])
    print("Total particles:", total)

    print("\nContamination Level:", level)
    print("Risk Percentage:", risk_percentage, "%")

    print("\nWater Usage Recommendation:")
    print("Drinking Water:", drinking)
    print("Irrigation:", irrigation)
    print("Aquatic Life Impact:", aquatic)

    print("\nRecommended Treatment Methods:")
    for t in treatment:
        print("-", t)

    print("\n==========================================")
# Out:
#   File "/tmp/ipykernel_10240/3248767050.py", line 1
#     def analyze_microplastic("/content/drive/MyDrive/MicroPlastic-7/valid/images/7_png_jpg.rf.d42f1f0391195eecedeb6d524b446928.jpg"):
#                              ^
# SyntaxError: invalid syntax

# %%
def analyze_microplastic(image_path):

    results = model.predict(source=image_path, conf=0.25)

    counts = {"fiber":0, "fragment":0, "film":0, "pellet":0}

    for r in results:
        for cls in r.boxes.cls:
            label = model.names[int(cls)].lower()

            if label == "pallet":
                label = "pellet"

            if label in counts:
                counts[label] += 1

    total = sum(counts.values())

    print("------ MICROPLASTIC REPORT ------")
    print("Fiber:", counts["fiber"])
    print("Fragment:", counts["fragment"])
    print("Film:", counts["film"])
    print("Pellet:", counts["pellet"])
    print("Total:", total)

# %%
analyze_microplastic("/content/drive/MyDrive/MicroPlastic-7/valid/images/7_png_jpg.rf.d42f1f0391195eecedeb6d524b446928.jpg")
# Out:
# image 1/1 /content/drive/MyDrive/MicroPlastic-7/valid/images/7_png_jpg.rf.d42f1f0391195eecedeb6d524b446928.jpg: 640x640 2 fibers, 2 films, 1 fragment, 3 pallets, 10.2ms
# Speed: 3.1ms preprocess, 10.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# ------ MICROPLASTIC REPORT ------
# Fiber: 2
# Fragment: 1
# Film: 2
# Pellet: 3
# Total: 8

# %%
def analyze_microplastic(image_path):

    results = model.predict(source=image_path, conf=0.25)

    counts = {"fiber":0, "fragment":0, "film":0, "pellet":0}

    for r in results:
        for cls in r.boxes.cls:
            label = model.names[int(cls)].lower()

            if label == "pallet":   # fix label spelling
                label = "pellet"

            if label in counts:
                counts[label] += 1

    total = sum(counts.values())

    # Risk percentage estimation
    risk_percentage = min(100, total * 8)

    # Water usability
    if total <= 3:
        drinking = "Safe after basic filtration"
        irrigation = "Safe"
        aquatic = "Low impact"
        level = "Low contamination"

    elif total <= 10:
        drinking = "Not recommended"
        irrigation = "Acceptable with filtration"
        aquatic = "Moderate risk"
        level = "Moderate contamination"

    else:
        drinking = "Unsafe"
        irrigation = "Unsafe without treatment"
        aquatic = "High risk to aquatic life"
        level = "High contamination"

    # Treatment suggestions
    treatment = [
        "Membrane filtration",
        "Activated carbon filtration",
        "Advanced oxidation process",
        "Ultrafiltration or nanofiltration",
        "Microplastic sedimentation tanks"
    ]

    print("\n====== MICROPLASTIC ANALYSIS REPORT ======\n")

    print("Particle Count:")
    print("Fiber:", counts["fiber"])
    print("Fragment:", counts["fragment"])
    print("Film:", counts["film"])
    print("Pellet:", counts["pellet"])
    print("Total particles:", total)

    print("\nContamination Level:", level)
    print("Risk Percentage:", risk_percentage, "%")

    print("\nWater Usage Recommendation:")
    print("Drinking Water:", drinking)
    print("Irrigation:", irrigation)
    print("Aquatic Life Impact:", aquatic)

    print("\nRecommended Treatment Methods:")
    for t in treatment:
        print("-", t)

    print("\n==========================================")

# %%
analyze_microplastic("/content/drive/MyDrive/MicroPlastic-7/valid/images/7_png_jpg.rf.d42f1f0391195eecedeb6d524b446928.jpg")
# Out:
# image 1/1 /content/drive/MyDrive/MicroPlastic-7/valid/images/7_png_jpg.rf.d42f1f0391195eecedeb6d524b446928.jpg: 640x640 2 fibers, 2 films, 1 fragment, 3 pallets, 8.9ms
# Speed: 2.7ms preprocess, 8.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# ====== MICROPLASTIC ANALYSIS REPORT ======
#
# Particle Count:
# Fiber: 2
# Fragment: 1
# Film: 2
# Pellet: 3
# Total particles: 8
#
# Contamination Level: Moderate contamination
# Risk Percentage: 64 %
#
# Water Usage Recommendation:
# Drinking Water: Not recommended
# Irrigation: Acceptable with filtration
# Aquatic Life Impact: Moderate risk
#
# Recommended Treatment Methods:
# - Membrane filtration
# - Activated carbon filtration
# - Advanced oxidation process
# - Ultrafiltration or nanofiltration
# - Microplastic sedimentation tanks
#
# ...

# %%
from IPython.display import Image, display

def analyze_microplastic(image_path):

    results = model.predict(
        source=image_path,
        conf=0.25,
        save=True,
        show_labels=True,
        show_conf=True
    )

    counts = {"fiber":0, "fragment":0, "film":0, "pellet":0}

    for r in results:
        for cls in r.boxes.cls:
            label = model.names[int(cls)].lower()

            if label == "pallet":
                label = "pellet"

            if label in counts:
                counts[label] += 1

    total = sum(counts.values())

    risk_percentage = min(100, total * 8)

    if total <= 3:
        level = "Low contamination"
        drinking = "Safe after filtration"
        irrigation = "Safe"
        aquatic = "Low impact"

    elif total <= 10:
        level = "Moderate contamination"
        drinking = "Not recommended"
        irrigation = "Acceptable with filtration"
        aquatic = "Moderate risk"

    else:
        level = "High contamination"
        drinking = "Unsafe"
        irrigation = "Unsafe without treatment"
        aquatic = "High risk to aquatic life"

    print("\n====== MICROPLASTIC ANALYSIS REPORT ======\n")

    print("Fiber:", counts["fiber"])
    print("Fragment:", counts["fragment"])
    print("Film:", counts["film"])
    print("Pellet:", counts["pellet"])
    print("Total particles:", total)

    print("\nContamination Level:", level)
    print("Risk Percentage:", risk_percentage,"%")

    print("\nWater Usage Recommendation")
    print("Drinking:", drinking)
    print("Irrigation:", irrigation)
    print("Aquatic Life:", aquatic)

    print("\nRecommended Treatment")
    print("- Membrane filtration")
    print("- Activated carbon filtration")
    print("- Ultrafiltration")
    print("- Advanced oxidation process")

    print("\n==========================================")

    output_image = "/content/runs/detect/predict/" + image_path.split("/")[-1]

    display(Image(filename=output_image))

# %%
analyze_microplastic("/content/drive/MyDrive/MicroPlastic-7/valid/images/7_png_jpg.rf.d42f1f0391195eecedeb6d524b446928.jpg")
# Out:
# image 1/1 /content/drive/MyDrive/MicroPlastic-7/valid/images/7_png_jpg.rf.d42f1f0391195eecedeb6d524b446928.jpg: 640x640 2 fibers, 2 films, 1 fragment, 3 pallets, 9.8ms
# Speed: 2.6ms preprocess, 9.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/detect/predict
#
# ====== MICROPLASTIC ANALYSIS REPORT ======
#
# Fiber: 2
# Fragment: 1
# Film: 2
# Pellet: 3
# Total particles: 8
#
# Contamination Level: Moderate contamination
# Risk Percentage: 64 %
#
# Water Usage Recommendation
# Drinking: Not recommended
# Irrigation: Acceptable with filtration
# Aquatic Life: Moderate risk
#
# Recommended Treatment
# - Membrane filtration
# - Activated carbon filtration
# - Ultrafiltration
# - Advanced oxidation process
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9a032639-a054-4ade-ba5d-389f6ff7b185" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9a032639-a054-4ade-ba5d-389f6ff7b185">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
analyze_microplastic("/content/sample_microplastic.jpg")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_10240/3230750804.py in <cell line: 0>()
# ----> 1 analyze_microplastic("/content/sample_microplastic.jpg")
#
# /tmp/ipykernel_10240/84952028.py in analyze_microplastic(image_path)
#       3 def analyze_microplastic(image_path):
#       4
# ----> 5     results = model.predict(
#       6         source=image_path,
#       7         conf=0.25,
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in predict(self, source, stream, predictor, **kwargs)
#     534         if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     535             self.predictor.set_prompts(prompts)
# --> 536         return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#     537
#     538     def track(
#
# ...

# %%
# !ls /content
# Out:
# '2_png_jpg.rf.1d6e254b57f231d26182a4b7a8f13513 (1).jpg'   sample_data
#  2_png_jpg.rf.1d6e254b57f231d26182a4b7a8f13513.jpg	  yolo26n.pt
#  drive							  yolov8n.pt
#  runs

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-53eeb489-5dab-431e-a535-49ccb6881952" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-53eeb489-5dab-431e-a535-49ccb6881952">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !ls /content
# Out:
# '2_png_jpg.rf.1d6e254b57f231d26182a4b7a8f13513 (1).jpg'   runs
# '2_png_jpg.rf.1d6e254b57f231d26182a4b7a8f13513 (2).jpg'   sample_data
#  2_png_jpg.rf.1d6e254b57f231d26182a4b7a8f13513.jpg	  yolo26n.pt
#  drive							  yolov8n.pt

# %%
analyze_microplastic("/content/water_sample.jpg")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_10240/2553344940.py in <cell line: 0>()
# ----> 1 analyze_microplastic("/content/water_sample.jpg")
#
# /tmp/ipykernel_10240/84952028.py in analyze_microplastic(image_path)
#       3 def analyze_microplastic(image_path):
#       4
# ----> 5     results = model.predict(
#       6         source=image_path,
#       7         conf=0.25,
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in predict(self, source, stream, predictor, **kwargs)
#     534         if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     535             self.predictor.set_prompts(prompts)
# --> 536         return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#     537
#     538     def track(
#
# ...

# %%
analyze_microplastic("/content/2_png_jpg.rf.1d6e254b57f231d26182a4b7a8f13513.jpg")
# Out:
# image 1/1 /content/2_png_jpg.rf.1d6e254b57f231d26182a4b7a8f13513.jpg: 640x640 1 fiber, 2 films, 1 fragment, 3 pallets, 9.2ms
# Speed: 2.6ms preprocess, 9.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/detect/predict
#
# ====== MICROPLASTIC ANALYSIS REPORT ======
#
# Fiber: 1
# Fragment: 1
# Film: 2
# Pellet: 3
# Total particles: 7
#
# Contamination Level: Moderate contamination
# Risk Percentage: 56 %
#
# Water Usage Recommendation
# Drinking: Not recommended
# Irrigation: Acceptable with filtration
# Aquatic Life: Moderate risk
#
# Recommended Treatment
# - Membrane filtration
# - Activated carbon filtration
# - Ultrafiltration
# - Advanced oxidation process
#
# ...

# %%
# !ls /content
# Out:
# '2_png_jpg.rf.1d6e254b57f231d26182a4b7a8f13513 (1).jpg'   runs
# '2_png_jpg.rf.1d6e254b57f231d26182a4b7a8f13513 (2).jpg'   sample_data
#  2_png_jpg.rf.1d6e254b57f231d26182a4b7a8f13513.jpg	  yolo26n.pt
#  drive							  yolov8n.pt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1ce038e9-b124-4fb6-83aa-e2f10799e963" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1ce038e9-b124-4fb6-83aa-e2f10799e963">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !ls /content
# Out:
# '2_png_jpg.rf.1d6e254b57f231d26182a4b7a8f13513 (1).jpg'
# '2_png_jpg.rf.1d6e254b57f231d26182a4b7a8f13513 (2).jpg'
#  2_png_jpg.rf.1d6e254b57f231d26182a4b7a8f13513.jpg
#  drive
#  runs
#  sample_data
# 'Screenshot 2026-03-16 190104.png'
#  yolo26n.pt
#  yolov8n.pt

# %%
analyze_microplastic("/content/water_sample.jpg")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_10240/2553344940.py in <cell line: 0>()
# ----> 1 analyze_microplastic("/content/water_sample.jpg")
#
# /tmp/ipykernel_10240/84952028.py in analyze_microplastic(image_path)
#       3 def analyze_microplastic(image_path):
#       4
# ----> 5     results = model.predict(
#       6         source=image_path,
#       7         conf=0.25,
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in predict(self, source, stream, predictor, **kwargs)
#     534         if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     535             self.predictor.set_prompts(prompts)
# --> 536         return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#     537
#     538     def track(
#
# ...

# %%
analyze_microplastic("/content/Screenshot 2026-03-16 190104.png")
# Out:
# image 1/1 /content/Screenshot 2026-03-16 190104.png: 384x640 22 fibers, 3 films, 2 fragments, 45.4ms
# Speed: 2.5ms preprocess, 45.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /content/runs/detect/predict
#
# ====== MICROPLASTIC ANALYSIS REPORT ======
#
# Fiber: 22
# Fragment: 2
# Film: 3
# Pellet: 0
# Total particles: 27
#
# Contamination Level: High contamination
# Risk Percentage: 100 %
#
# Water Usage Recommendation
# Drinking: Unsafe
# Irrigation: Unsafe without treatment
# Aquatic Life: High risk to aquatic life
#
# Recommended Treatment
# - Membrane filtration
# - Activated carbon filtration
# - Ultrafiltration
# - Advanced oxidation process
#
# ...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_10240/1986760627.py in <cell line: 0>()
# ----> 1 analyze_microplastic("/content/Screenshot 2026-03-16 190104.png")
#
# ...

# %%
from IPython.display import Image, display

def analyze_microplastic(image_path):

    results = model.predict(source=image_path, conf=0.25)

    counts = {"fiber":0, "fragment":0, "film":0, "pellet":0}

    for r in results:
        for cls in r.boxes.cls:
            label = model.names[int(cls)].lower()
            if label in counts:
                counts[label] += 1

    total = sum(counts.values())

    print("\n====== MICROPLASTIC ANALYSIS REPORT ======\n")
    print("Fiber:", counts["fiber"])
    print("Fragment:", counts["fragment"])
    print("Film:", counts["film"])
    print("Pellet:", counts["pellet"])
    print("Total particles:", total)

    # Show detected image
    for r in results:
        display(Image(filename=r.save_dir + "/" + r.path.split("/")[-1]))

# %%
analyze_microplastic("/content/Screenshot 2026-03-16 190104.png")
# Out:
# image 1/1 /content/Screenshot 2026-03-16 190104.png: 384x640 22 fibers, 3 films, 2 fragments, 9.5ms
# Speed: 2.1ms preprocess, 9.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# ====== MICROPLASTIC ANALYSIS REPORT ======
#
# Fiber: 22
# Fragment: 2
# Film: 3
# Pellet: 0
# Total particles: 27
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_10240/1986760627.py in <cell line: 0>()
# ----> 1 analyze_microplastic("/content/Screenshot 2026-03-16 190104.png")
#
# /tmp/ipykernel_10240/2756169636.py in analyze_microplastic(image_path)
#      24     # Show detected image
#      25     for r in results:
# ---> 26         display(Image(filename=r.save_dir + "/" + r.path.split("/")[-1]))
#
# ...

# %%
from IPython.display import display
import matplotlib.pyplot as plt

def analyze_microplastic(image_path):

    results = model.predict(source=image_path, conf=0.25)

    counts = {"fiber":0, "fragment":0, "film":0, "pellet":0}

    for r in results:
        for cls in r.boxes.cls:
            label = model.names[int(cls)].lower()
            if label in counts:
                counts[label] += 1

    total = sum(counts.values())

    print("\n====== MICROPLASTIC ANALYSIS REPORT ======\n")
    print("Fiber:", counts["fiber"])
    print("Fragment:", counts["fragment"])
    print("Film:", counts["film"])
    print("Pellet:", counts["pellet"])
    print("Total particles:", total)

    # Show image with bounding boxes
    for r in results:
        im = r.plot()
        plt.imshow(im)
        plt.axis("off")
        plt.show()

# %%
analyze_microplastic("/content/Screenshot 2026-03-16 190104.png")
# Out:
# image 1/1 /content/Screenshot 2026-03-16 190104.png: 384x640 22 fibers, 3 films, 2 fragments, 9.1ms
# Speed: 2.7ms preprocess, 9.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# ====== MICROPLASTIC ANALYSIS REPORT ======
#
# Fiber: 22
# Fragment: 2
# Film: 3
# Pellet: 0
# Total particles: 27

# %%
from IPython.display import display
import matplotlib.pyplot as plt

def analyze_microplastic(image_path):

    results = model.predict(source=image_path, conf=0.25)

    counts = {"fiber":0, "fragment":0, "film":0, "pellet":0}

    for r in results:
        for cls in r.boxes.cls:
            label = model.names[int(cls)].lower()
            if label in counts:
                counts[label] += 1

    total = sum(counts.values())

    # Risk calculation
    risk_percentage = min(100, total * 8)

    if risk_percentage < 30:
        contamination = "Low contamination"
        drinking = "Safe with basic filtration"
        irrigation = "Safe"
        aquatic = "Low risk"
    elif risk_percentage < 70:
        contamination = "Moderate contamination"
        drinking = "Not recommended"
        irrigation = "Acceptable with filtration"
        aquatic = "Moderate risk"
    else:
        contamination = "High contamination"
        drinking = "Unsafe"
        irrigation = "Unsafe without treatment"
        aquatic = "High risk to aquatic life"

    print("\n====== MICROPLASTIC ANALYSIS REPORT ======\n")

    print("Fiber:", counts["fiber"])
    print("Fragment:", counts["fragment"])
    print("Film:", counts["film"])
    print("Pellet:", counts["pellet"])
    print("Total particles:", total)

    print("\nContamination Level:", contamination)
    print("Risk Percentage:", risk_percentage, "%")

    print("\nWater Usage Recommendation")
    print("Drinking:", drinking)
    print("Irrigation:", irrigation)
    print("Aquatic Life:", aquatic)

    print("\nRecommended Treatment")
    print("- Membrane filtration")
    print("- Activated carbon filtration")
    print("- Ultrafiltration")
    print("- Advanced oxidation process")

    print("\n==========================================")

    # Show detected image with bounding boxes
    for r in results:
        im = r.plot()
        plt.imshow(im)
        plt.axis("off")
        plt.show()

# %%
analyze_microplastic("/content/Screenshot 2026-03-16 190104.png")
# Out:
# image 1/1 /content/Screenshot 2026-03-16 190104.png: 384x640 22 fibers, 3 films, 2 fragments, 8.0ms
# Speed: 2.6ms preprocess, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# ====== MICROPLASTIC ANALYSIS REPORT ======
#
# Fiber: 22
# Fragment: 2
# Film: 3
# Pellet: 0
# Total particles: 27
#
# Contamination Level: High contamination
# Risk Percentage: 100 %
#
# Water Usage Recommendation
# Drinking: Unsafe
# Irrigation: Unsafe without treatment
# Aquatic Life: High risk to aquatic life
#
# Recommended Treatment
# - Membrane filtration
# - Activated carbon filtration
# - Ultrafiltration
# - Advanced oxidation process
#
# ...

# %%
# !find /content -name "best.pt"
# Out:
# /content/runs/detect/train/weights/best.pt
# /content/drive/MyDrive/runs/detect/train/weights/best.pt

# %%
# !ls /content/drive/MyDrive/runs/detect/train/weights
# Out:
# best.pt  last.pt

# %%
# !mkdir /content/drive/MyDrive/Microplastic_Project
# Out:
# mkdir: cannot create directory ‘/content/drive/MyDrive/Microplastic_Project’: File exists

# %%
# !ls /content/drive/MyDrive/Microplastic_Project
# Out:
# ls: cannot access '/content/drive/MyDrive/Microplastic_Project': No such file or directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive
# Out:
# 'Audio_Signal_Filtering(2).gslides'   MicroPlastic-7	     runs
# 'Colab Notebooks'		      microplastic_dataset
#  EDP_F2.gdoc			      Microplastic_Project

# %%
# !find /content/drive/MyDrive -name "best.pt"
# Out:
# /content/drive/MyDrive/runs/detect/train/weights/best.pt

# %%
# !mkdir /content/drive/MyDrive/Microplastic_Project
# Out:
# mkdir: cannot create directory ‘/content/drive/MyDrive/Microplastic_Project’: File exists

# %%
# !cp /content/drive/MyDrive/runs/detect/train/weights/best.pt /content/drive/MyDrive/Microplastic_Project/microplastic_model.pt

# %%
# !ls /content/drive/MyDrive/Microplastic_Project
# Out:
# Dataset  microplastic_model.pt
